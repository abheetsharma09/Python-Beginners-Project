# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("finalDATA.csv")

df.head(5)
# Out:
#    Sl No                                       product_name  \
# 0      1  Samsung Galaxy Book4 Metal Intel Core i5 13th ...
# 1      2  Samsung Galaxy Book4 Metal Intel Core i3 13th ...
# 2      3  Acer Aspire 15 MS Office 2024 + M365 Basic, AM...
# 3      4  ASUS Vivobook 15 (2025) with Office 2024 + M36...
# 4      5  ASUS ExpertBook P1 (i3 14th Gen) with 1 Yr ADP...
#
#                                     product_imageSRC  product_price_in_inr  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...               55311.0
# 1  https://rukminim2.flixcart.com/image/312/312/x...               51990.0
# 2  https://rukminim2.flixcart.com/image/312/312/x...               39990.0
# 3  https://rukminim2.flixcart.com/image/312/312/x...               42990.0
# 4  https://rukminim2.flixcart.com/image/312/312/x...               50990.0
#
#    product_rating  product_total_ratings  product_total_reviews  \
# 0             4.4                  19735                   2048
# ...

# %%
plt.hist(df["product_discount"] )
# plt.scatter(df["product_rating"] , df["product_discount"])
# Out:
# (array([19., 22., 23.,  4.,  3., 25., 15., 24.,  3.,  1.]),
#  array([ 1. ,  6.1, 11.2, 16.3, 21.4, 26.5, 31.6, 36.7, 41.8, 46.9, 52. ]),
#  <BarContainer object of 10 artists>)
